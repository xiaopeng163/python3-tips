# %%
import os

path = '/Users/pengxiao/Documents/tmp'

def get_file(folder_name):
    for item in os.listdir(folder_name):
        full_path = os.path.join(folder_name, item)
        if os.path.isfile(full_path):
            yield full_path
        elif os.path.isdir(full_path):
            # ???????
            # for item in get_file(full_path):
            #    yield item
            yield from get_file(full_path)

for file_name in get_file(path):
    print(file_name)
# Out:
# /Users/pengxiao/Documents/tmp/test1/4.text
# /Users/pengxiao/Documents/tmp/test1/test2/5.txt
# /Users/pengxiao/Documents/tmp/test1/3.text
# /Users/pengxiao/Documents/tmp/2.txt
# /Users/pengxiao/Documents/tmp/1.txt
